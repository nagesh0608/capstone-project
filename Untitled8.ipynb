# %% [markdown]
# # ==============================
# #  Data Collection & Cleaning
# # ==============================

# %% [markdown]
# ## Importing Data Set

# %%
import pandas as pd
df = pd.read_excel("studentperformance.xlsx")

# %% [markdown]
# ## Getting First Five rows of data set

# %%
df.head()
# Out:
#    Sno school sex   age  Medu  Fedu     Mjob      Fjob  reason  traveltime  \
# 0  0.0     GP   F  18.0   4.0   4.0  at_home   teacher  course         2.0
# 1  1.0     GP   F  17.0   1.0   1.0  at_home     other  course         1.0
# 2  2.0     GP   F  15.0   1.0   1.0  at_home     other   other         1.0
# 3  3.0     GP   F  15.0   4.0   2.0   health  services    home         1.0
# 4  4.0     GP   F  16.0   3.0   3.0    other     other    home         1.0
#
#    ...  higher  internet famrel freetime goout health absences    G1    G2  \
# 0  ...     yes        no    4.0      3.0   4.0    3.0      6.0   5.0   6.0
# 1  ...     yes       yes    5.0      3.0   3.0    3.0      4.0   5.0   5.0
# 2  ...     yes       yes    4.0      3.0   2.0    3.0     10.0   7.0   8.0
# 3  ...     yes       yes    3.0      2.0   2.0    5.0      2.0  15.0  14.0
# 4  ...     yes        no    4.0      3.0   2.0    5.0      4.0   6.0  10.0
#
#      G3
# 0   6.0
# 1   6.0
# 2  10.0
# 3  15.0
# 4  10.0
#
# ...

# %% [markdown]
# ## checking data shape and column names and data types

# %%
df.shape
# Out:
# (398, 26)

# %%
df.columns
# Out:
# Index(['Sno', 'school', 'sex', 'age', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason',
#        'traveltime', 'studytime', 'failures', 'schoolsup', 'famsup', 'paid',
#        'activities', 'higher', 'internet', 'famrel', 'freetime', 'goout',
#        'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Sno           float64
# school         object
# sex            object
# age           float64
# Medu          float64
# Fedu          float64
# Mjob           object
# Fjob           object
# reason         object
# traveltime    float64
# studytime     float64
# failures      float64
# schoolsup      object
# famsup         object
# paid           object
# activities     object
# higher         object
# internet       object
# famrel        float64
# freetime      float64
# goout         float64
# health        float64
# absences      float64
# G1            float64
# G2            float64
# G3            float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 26 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Sno         395 non-null    float64
#  1   school      395 non-null    object
#  2   sex         395 non-null    object
#  3   age         395 non-null    float64
#  4   Medu        395 non-null    float64
#  5   Fedu        395 non-null    float64
#  6   Mjob        395 non-null    object
#  7   Fjob        395 non-null    object
#  8   reason      398 non-null    object
#  9   traveltime  390 non-null    float64
#  10  studytime   385 non-null    float64
#  11  failures    395 non-null    float64
#  12  schoolsup   395 non-null    object
#  13  famsup      395 non-null    object
#  14  paid        395 non-null    object
#  15  activities  395 non-null    object
#  16  higher      395 non-null    object
#  17  internet    395 non-null    object
#  18  famrel      395 non-null    float64
# ...

# %% [markdown]
# ## Handiling Missing values

# %%
print("Printing values before cleaning: \n")
df.isnull().sum()
# Out:
# Printing values before cleaning:
# Sno            3
# school         3
# sex            3
# age            3
# Medu           3
# Fedu           3
# Mjob           3
# Fjob           3
# reason         0
# traveltime     8
# studytime     13
# failures       3
# schoolsup      3
# famsup         3
# paid           3
# activities     3
# higher         3
# internet       3
# famrel         3
# freetime       3
# goout          3
# health         3
# absences       3
# G1            10
# G2            11
# G3            12
# dtype: int64

# %% [markdown]
# ## Remove rows which are null in Sno

# %%
df = df.dropna(subset=['Sno'])

# %%
#df.drop(columns=['Sno'], inplace=True)

# %% [markdown]
# ## handling numerical calumns

# %%
num_col = df.select_dtypes(include=['float64','int64']).columns

# %%
num_col
# Out:
# Index(['Sno', 'age', 'Medu', 'Fedu', 'traveltime', 'studytime', 'failures',
#        'famrel', 'freetime', 'goout', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
cat_col = df.select_dtypes(include=['object']).columns

# %%
cat_col
# Out:
# Index(['school', 'sex', 'Mjob', 'Fjob', 'reason', 'schoolsup', 'famsup',
#        'paid', 'activities', 'higher', 'internet'],
#       dtype='object')

# %%
for col in num_col:
    df[col] = df[col].fillna(df[col].median())

# %%
df.isnull().sum()
# Out:
# Sno           0
# school        3
# sex           3
# age           0
# Medu          0
# Fedu          0
# Mjob          3
# Fjob          3
# reason        0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     3
# famsup        3
# paid          3
# activities    3
# higher        3
# internet      3
# famrel        0
# freetime      0
# goout         0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
cat_cols = df.select_dtypes(include=['object']).columns
df[cat_cols].isnull().sum()
# Out:
# school        3
# sex           3
# Mjob          3
# Fjob          3
# reason        0
# schoolsup     3
# famsup        3
# paid          3
# activities    3
# higher        3
# internet      3
# dtype: int64

# %%
for col in cat_col:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
df.isnull().sum()
# Out:
# Sno           0
# school        0
# sex           0
# age           0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# higher        0
# internet      0
# famrel        0
# freetime      0
# goout         0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64
