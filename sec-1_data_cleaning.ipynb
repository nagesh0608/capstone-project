# %% [markdown]
# ## Data Cleaning

# %%
import pandas as pd

# %%
df = pd.read_csv("retail_data.csv")

# %%
df.head()
# Out:
#                 event_time event type  product_id   category_id  \
# 0  2019-11-01 00:06:51 UTC       view   1001588.0  2.050000e+18
# 1  2019-11-01 00:08:03 UTC       view   1002101.0  2.050000e+18
# 2  2019-11-01 00:16:56 UTC       view   1002101.0           NaN
# 3  2019-11-01 00:19:17 UTC       view   1002101.0  2.050000e+18
# 4  2019-11-01 00:27:56 UTC       view   1002101.0  2.050000e+18
#
#             category_code     brand   price      user_id  \
# 0  electronics.smartphone     meizu  127.87  528269305.0
# 1  electronics.smartphone   samsung  370.64  540508491.0
# 2  electronics.smartphone   samsung  370.64          NaN
# 3  electronics.smartphone   samsung  370.64  565859861.0
# 4  electronics.smartphone   samsung  370.64  515031178.0
#
#                            user_session
# 0  6dce75d2-e455-4e52-ab65-af16e36f64cb
# 1  33a0d8f4-c388-4ce7-85f4-7b1f11563d6a
# 2  8f65dac1-e176-4b72-b783-d9c5615ae858
# 3  e280986e-033c-4394-a0df-73354b42b80c
# ...

# %% [markdown]
# ### To check,data shape,columns and datatypes

# %%
df.shape
# Out:
# (5005, 9)

# %%
df.columns
# Out:
# Index(['event_time', 'event type', 'product_id', 'category_id',
#        'category_code', 'brand', 'price', 'user_id', 'user_session'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5005 entries, 0 to 5004
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   event_time     5005 non-null   object
#  1   event type     5005 non-null   object
#  2   product_id     4985 non-null   float64
#  3   category_id    4996 non-null   float64
#  4   category_code  3151 non-null   object
#  5   brand          4088 non-null   object
#  6   price          5000 non-null   float64
#  7   user_id        4993 non-null   float64
#  8   user_session   5001 non-null   object
# dtypes: float64(4), object(5)
# memory usage: 352.0+ KB

# %%
df['product_id'] = df['product_id'].astype('Int64')

# %%
df.head()
# Out:
#                 event_time event type  product_id   category_id  \
# 0  2019-11-01 00:06:51 UTC       view     1001588  2.050000e+18
# 1  2019-11-01 00:08:03 UTC       view     1002101  2.050000e+18
# 2  2019-11-01 00:16:56 UTC       view     1002101           NaN
# 3  2019-11-01 00:19:17 UTC       view     1002101  2.050000e+18
# 4  2019-11-01 00:27:56 UTC       view     1002101  2.050000e+18
#
#             category_code     brand   price      user_id  \
# 0  electronics.smartphone     meizu  127.87  528269305.0
# 1  electronics.smartphone   samsung  370.64  540508491.0
# 2  electronics.smartphone   samsung  370.64          NaN
# 3  electronics.smartphone   samsung  370.64  565859861.0
# 4  electronics.smartphone   samsung  370.64  515031178.0
#
#                            user_session
# 0  6dce75d2-e455-4e52-ab65-af16e36f64cb
# 1  33a0d8f4-c388-4ce7-85f4-7b1f11563d6a
# 2  8f65dac1-e176-4b72-b783-d9c5615ae858
# 3  e280986e-033c-4394-a0df-73354b42b80c
# ...

# %%
df['category_id'] = df['category_id'].astype('Int64')

# %%
df['user_id'] = df['user_id'].astype('Int64')

# %%
df.head(2)
# Out:
#                 event_time event type  product_id          category_id  \
# 0  2019-11-01 00:06:51 UTC       view     1001588  2050000000000000000
# 1  2019-11-01 00:08:03 UTC       view     1002101  2050000000000000000
#
#             category_code     brand   price    user_id  \
# 0  electronics.smartphone     meizu  127.87  528269305
# 1  electronics.smartphone   samsung  370.64  540508491
#
#                            user_session
# 0  6dce75d2-e455-4e52-ab65-af16e36f64cb
# 1  33a0d8f4-c388-4ce7-85f4-7b1f11563d6a

# %%
df.isnull().sum()   # checking for null values
# Out:
# event_time          0
# event type          0
# product_id         20
# category_id         9
# category_code    1854
# brand             917
# price               5
# user_id            12
# user_session        4
# dtype: int64

# %%
df = df.dropna(subset=['user_id'])

# %%
df.shape
# Out:
# (4993, 9)

# %%
df.isnull().sum()
# Out:
# event_time          0
# event type          0
# product_id         19
# category_id         6
# category_code    1851
# brand             915
# price               5
# user_id             0
# user_session        4
# dtype: int64

# %%
print(df.isnull().sum().sum())
# Out:
# 2800

# %% [markdown]
# ## Checking Duplicates rows

# %%
print(df.duplicated().sum())
# Out:
# 5

# %%
 df = df.drop_duplicates()

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# event_time          0
# event type          0
# product_id         19
# category_id         6
# category_code    1851
# brand             915
# price               5
# user_id             0
# user_session        4
# dtype: int64

# %%
df = df.copy()
df['price'] = df['price'].fillna(df['price'].mean())

# %%
df.isnull().sum()
# Out:
# event_time          0
# event type          0
# product_id         19
# category_id         6
# category_code    1851
# brand             915
# price               0
# user_id             0
# user_session        4
# dtype: int64

# %%
num_col = df.select_dtypes( include=['Int64','float64']).columns

# %%
num_col
# Out:
# Index(['product_id', 'category_id', 'price', 'user_id'], dtype='object')

# %%
cat_col = df.select_dtypes(include=['object']).columns

# %%
cat_col
# Out:
# Index(['event_time', 'event type', 'category_code', 'brand', 'user_session'], dtype='object')

# %%
for col in cat_col:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
df.isnull().sum()
# Out:
# event_time        0
# event type        0
# product_id       19
# category_id       6
# category_code     0
# brand             0
# price             0
# user_id           0
# user_session      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4988 entries, 0 to 4999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   event_time     4988 non-null   object
#  1   event type     4988 non-null   object
#  2   product_id     4969 non-null   Int64
#  3   category_id    4982 non-null   Int64
#  4   category_code  4988 non-null   object
#  5   brand          4988 non-null   object
#  6   price          4988 non-null   float64
#  7   user_id        4988 non-null   Int64
#  8   user_session   4988 non-null   object
# dtypes: Int64(3), float64(1), object(5)
# memory usage: 404.3+ KB

# %%
df['product_id'] = df['product_id'].fillna(0)

# %%
df['category_id'] = df['category_id'].fillna(0)

# %%
df.isnull().sum()
# Out:
# event_time       0
# event type       0
# product_id       0
# category_id      0
# category_code    0
# brand            0
# price            0
# user_id          0
# user_session     0
# dtype: int64

# %%
df.head(2)
# Out:
#                 event_time event type  product_id          category_id  \
# 0  2019-11-01 00:06:51 UTC       view     1001588  2050000000000000000
# 1  2019-11-01 00:08:03 UTC       view     1002101  2050000000000000000
#
#             category_code     brand   price    user_id  \
# 0  electronics.smartphone     meizu  127.87  528269305
# 1  electronics.smartphone   samsung  370.64  540508491
#
#                            user_session
# 0  6dce75d2-e455-4e52-ab65-af16e36f64cb
# 1  33a0d8f4-c388-4ce7-85f4-7b1f11563d6a

# %% [markdown]
# ## Consistency Checking

# %%
df['brand'].unique()
# Out:
# array(['meizu', ' samsung', 'samsung', 'apple', 'xiaomi', 'huawei',
#        'nokia', 'APPLE', 'oneplus', 'zte', 'sony', 'honor', 'lg', 'bq',
#        'Samsung', 'tp-link', 'oppo', 'blackberry', 'vivo', 'htc',
#        'lenovo', 'acer', 'irbis', 'hp', 'dell', 'asus', 'avalon',
#        'netechnics', 'neo', 'smart', 'pulser', 'xerox', 'epson',
#        'lexmark', 'canon', 'philips', 'aoc', 'toshiba', 'haier', 'yasin',
#        'artel', 'hisense', 'tcl', 'changhong', 'kivi', 'shivaki',
#        'horizont', 'ergo', 'blaupunkt', 'arg', 'nikon', 'gopro', 'turbo',
#        'hansa', 'midea', 'electrolux', 'elenberg', 'gefest', 'dauscher',
#        'flama', 'gorenje', 'bosch', 'atlant', 'pozis', 'indesit', 'beko',
#        'whirlpool', 'hotpoint-ariston', 'vitek', 'redmond', 'moulinex',
#        'tefal', 'polaris', 'candy', 'thomas', 'arnica', 'karcher',
#        'maxwell', 'braun', 'ariston', 'aqua', 'oasis', 'timberk',
#        'scarlett', 'delonghi', 'smeg', 'neoline', 'anytek', 'jbl',
# ...

# %%
df['brand'].nunique()
# Out:
# 481

# %%
df['brand'] = df['brand'].str.strip()

# %%
df['brand'] = df['brand'].str.lower()

# %%
df['brand'].unique()
# Out:
# array(['meizu', 'samsung', 'apple', 'xiaomi', 'huawei', 'nokia',
#        'oneplus', 'zte', 'sony', 'honor', 'lg', 'bq', 'tp-link', 'oppo',
#        'blackberry', 'vivo', 'htc', 'lenovo', 'acer', 'irbis', 'hp',
#        'dell', 'asus', 'avalon', 'netechnics', 'neo', 'smart', 'pulser',
#        'xerox', 'epson', 'lexmark', 'canon', 'philips', 'aoc', 'toshiba',
#        'haier', 'yasin', 'artel', 'hisense', 'tcl', 'changhong', 'kivi',
#        'shivaki', 'horizont', 'ergo', 'blaupunkt', 'arg', 'nikon',
#        'gopro', 'turbo', 'hansa', 'midea', 'electrolux', 'elenberg',
#        'gefest', 'dauscher', 'flama', 'gorenje', 'bosch', 'atlant',
#        'pozis', 'indesit', 'beko', 'whirlpool', 'hotpoint-ariston',
#        'vitek', 'redmond', 'moulinex', 'tefal', 'polaris', 'candy',
#        'thomas', 'arnica', 'karcher', 'maxwell', 'braun', 'ariston',
#        'aqua', 'oasis', 'timberk', 'scarlett', 'delonghi', 'smeg',
# ...

# %%
df['brand'].nunique()
# Out:
# 478

# %%
df.head(2)
# Out:
#                 event_time event type  product_id          category_id  \
# 0  2019-11-01 00:06:51 UTC       view     1001588  2050000000000000000
# 1  2019-11-01 00:08:03 UTC       view     1002101  2050000000000000000
#
#             category_code    brand   price    user_id  \
# 0  electronics.smartphone    meizu  127.87  528269305
# 1  electronics.smartphone  samsung  370.64  540508491
#
#                            user_session
# 0  6dce75d2-e455-4e52-ab65-af16e36f64cb
# 1  33a0d8f4-c388-4ce7-85f4-7b1f11563d6a

# %%
df[df['price']<0]
# Out:
#                    event_time event type  product_id          category_id  \
# 4643  2019-11-01 00:25:52 UTC       view    32401217  2050000000000000000
# 4818  2019-11-01 00:00:35 UTC       view    44300009  2100000000000000000
#
#                category_code    brand  price    user_id  \
# 4643  electronics.smartphone  samsung -27.03  512483076
# 4818           apparel.jeans  samsung -50.45  545220871
#
#                               user_session
# 4643  5e3606fe-e6ba-457e-973c-d56822d9584e
# 4818  f278cca0-e0f6-49a3-819a-d961998282d5

# %%
df['price'] = df['price'].abs()

# %%
df[df['price']<0]
# Out:
# Empty DataFrame
# Columns: [event_time, event type, product_id, category_id, category_code, brand, price, user_id, user_session]
# Index: []

# %% [markdown]
# #  Identify the type of each variable: Nominal, Ordinal, Discrete, Continuous

# %%
df.dtypes
# Out:
# event_time        object
# event type        object
# product_id         Int64
# category_id        Int64
# category_code     object
# brand             object
# price            float64
# user_id            Int64
# user_session      object
# dtype: object

# %%
df.head(2)
# Out:
#                 event_time event type  product_id          category_id  \
# 0  2019-11-01 00:06:51 UTC       view     1001588  2050000000000000000
# 1  2019-11-01 00:08:03 UTC       view     1002101  2050000000000000000
#
#             category_code    brand   price    user_id  \
# 0  electronics.smartphone    meizu  127.87  528269305
# 1  electronics.smartphone  samsung  370.64  540508491
#
#                            user_session
# 0  6dce75d2-e455-4e52-ab65-af16e36f64cb
# 1  33a0d8f4-c388-4ce7-85f4-7b1f11563d6a

# %% [markdown]
#  # What is the distribution of products based on product_id?

# %%
df['product_id'].sort_values()
# Out:
# 3131           0
# 18             0
# 58             0
# 72             0
# 90             0
#           ...
# 4995    60500001
# 4996    60500001
# 4998    60500002
# 4997    60500002
# 4999    60500002
# Name: product_id, Length: 4988, dtype: Int64

# %%
df['brand'].sort_values().head(10)
# Out:
# 3670    a-case
# 3669    a-case
# 3653    a-case
# 3668    a-case
# 1146      acer
# 1162      acer
# 1163      acer
# 1164      acer
# 1176      acer
# 1177      acer
# Name: brand, dtype: object

# %% [markdown]
# # How many unique users are present in the dataset (user_id)?

# %%
df['user_id'].nunique()
# Out:
# 1113

# %% [markdown]
#   # Are there any missing values in the dataset?

# %%
print(df.isnull().sum().sum())
# Out:
# 2821

# %% [markdown]
# #  Are the event types valid (view, cart, purchase)?

# %%
df['event type'].unique()
yes
# Out:
# array(['view', 'purchase', 'cart'], dtype=object)

# %%
#total_cells = df.size
#missing_celss = df.isnull().sum().sum()
#non_missing_values = total_cells-missing_celss
#accuracy = (non_missing_values/total_cells )*100

# %%
#accuracy
