# %% [markdown]
# # ==============================
# #  Data Collection & Cleaning
# # ==============================

# %% [markdown]
# # STEP 1: load data set

# %%
# importing Libraries
import pandas as pd

# %%
#----- 1. Load Dataset ----
df = pd.read_csv('mixed_dataset_6000.csv')

# %%
import pandas as pd

# Read only first 5000 rows
#df = pd.read_csv('2019-Nov.csv', nrows=5000)

# Save extracted data
#df.to_csv("retail_data_5000.csv", index=False)

# %%
df['category_id'] = df['category_id'].astype(str)

# %%
#pd.options.display.float_format = '{:.0f}'.format

# %%
df.head()
# Out:
#                 event_time event_type  product_id         category_id  \
# 0  2019-11-01 00:00:00 UTC       view     1003461 2053013555631882752
# 1  2019-11-01 00:00:00 UTC       view     5000088 2053013566100866048
# 2  2019-11-01 00:00:01 UTC       view    17302664 2053013553853497600
# 3  2019-11-01 00:00:01 UTC       view     3601530 2053013563810776064
# 4  2019-11-01 00:00:01 UTC       view     1004775 2053013555631882752
#
#                category_code   brand  price   user_id  \
# 0     electronics.smartphone  xiaomi    489 520088904
# 1  appliances.sewing_machine  janome    294 530496790
# 2                        NaN   creed     28 561587266
# 3  appliances.kitchen.washer      lg    713 518085591
# 4     electronics.smartphone  xiaomi    183 558856683
#
#                            user_session
# 0  4d3b30da-a5e4-49df-b1a8-ba5943f1dd33
# 1  8e5f4f83-366c-4f70-860e-ca7417414283
# 2  755422e7-9040-477b-9bd2-6a6e8fd97387
# 3  3bfb58cd-7892-48cc-8020-2f17e6de6e7f
# ...

# %%
df.dtypes
# Out:
# event_time        object
# event_type        object
# product_id       float64
# category_id      float64
# category_code     object
# brand             object
# price            float64
# user_id          float64
# user_session      object
# dtype: object

# %%
df.shape
# Out:
# (6000, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   event_time     5819 non-null   object
#  1   event_type     5840 non-null   object
#  2   product_id     5800 non-null   float64
#  3   category_id    5800 non-null   float64
#  4   category_code  3747 non-null   object
#  5   brand          4791 non-null   object
#  6   price          5800 non-null   float64
#  7   user_id        5800 non-null   float64
#  8   user_session   5839 non-null   object
# dtypes: float64(4), object(5)
# memory usage: 422.0+ KB

# %% [markdown]
# # STEP 2: Check Shape, Columns, Info

# %%
print("Missing Values BEFORE:\n")
print(df.isnull().sum())
# Out:
# Missing Values BEFORE:
#
# event_time        181
# event_type        160
# product_id        200
# category_id       200
# category_code    2253
# brand            1209
# price             200
# user_id           200
# user_session      161
# dtype: int64

# %%
#df['user_session'] = df['user_session'].fillna(df['user_session'].mode()[0])
#df['user_session'] = df['user_session'].fillna(df['user_session'].mean())
#df['user_session'] = df['user_session'].fillna('Unknown')
df = df.dropna(subset=['user_session'])

# %%
#df = df['category_code'].fillna('Unknown', inplace = True)
df['category_code'] = df['category_code'].fillna('Unknown')

# %%
df['brand'] = df['brand'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# event_time       0
# event_type       0
# product_id       0
# category_id      0
# category_code    0
# brand            0
# price            0
# user_id          0
# user_session     0
# dtype: int64

# %%
df.shape
# Out:
# (67501969, 9)

# %%
df.head()
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2019-11-01 00:00:00 UTC       view     1003461  2053013555631882655
# 1  2019-11-01 00:00:00 UTC       view     5000088  2053013566100866035
# 2  2019-11-01 00:00:01 UTC       view    17302664  2053013553853497655
# 3  2019-11-01 00:00:01 UTC       view     3601530  2053013563810775923
# 4  2019-11-01 00:00:01 UTC       view     1004775  2053013555631882655
#
#                category_code   brand   price    user_id  \
# 0     electronics.smartphone  xiaomi  489.07  520088904
# 1  appliances.sewing_machine  janome  293.65  530496790
# 2                    Unknown   creed   28.31  561587266
# 3  appliances.kitchen.washer      lg  712.87  518085591
# 4     electronics.smartphone  xiaomi  183.27  558856683
#
#                            user_session
# 0  4d3b30da-a5e4-49df-b1a8-ba5943f1dd33
# 1  8e5f4f83-366c-4f70-860e-ca7417414283
# 2  755422e7-9040-477b-9bd2-6a6e8fd97387
# ...

# %%
df = df[df['category_code'] == 'Unknown']

# %%
df
# Out:
#                        event_time event_type  product_id          category_id  \
# 2         2019-11-01 00:00:01 UTC       view    17302664  2053013553853497655
# 7         2019-11-01 00:00:02 UTC       view    15900065  2053013558190408249
# 8         2019-11-01 00:00:02 UTC       view    12708937  2053013553559896355
# 13        2019-11-01 00:00:04 UTC       view    34600011  2060981320581906480
# 15        2019-11-01 00:00:06 UTC       view    24900193  2053013562183385881
# ...                           ...        ...         ...                  ...
# 67501963  2019-11-30 23:59:53 UTC       view    31500157  2053013558031024687
# 67501964  2019-11-30 23:59:53 UTC       view    12711053  2053013553559896355
# 67501968  2019-11-30 23:59:54 UTC       view     3300318  2053013555355058573
# 67501973  2019-11-30 23:59:57 UTC       view    10502879  2053013553199186187
# 67501974  2019-11-30 23:59:58 UTC       view    15700137  2053013559733912211
#
# ...
