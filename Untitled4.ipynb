# %% [markdown]
# # =====================================================
# # Python Basics
# # Author: Nagesh  , KL University Hyderabad
# # Objective: Learn Python fundamentals for Data Science - Part 1
# # =====================================================

# %%
print("This KL University")
# Out:
# This KL University

# %%
a=7

# %%
b = 8

# %%
a+b
# Out:
# 15

# %%
print(a+b)
# Out:
# 15

# %%
ans = a+b

# %%
print("sum of a and b",ans)
# Out:
# sum of a and b 15

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(2,6):
    print(i)
# Out:
# 2
# 3
# 4
# 5

# %%
for i in range(2,21,2):
    print(i)

# %%
##
