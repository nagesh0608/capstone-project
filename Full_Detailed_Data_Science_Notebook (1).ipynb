# %% [markdown]
# # 📊 Data Science - Complete NotesData Science is an interdisciplinary field that uses scientific methods, algorithms, and systems to extract knowledge and insights from data.It combines:- Statistics- Computer Science- Domain Knowledge

# %% [markdown]
# ## 🎯 Key Goals- Extract meaningful insights- Support decision-making- Predict future trends

# %% [markdown]
# ## 📂 Types of Data### Structured Data- Organized in rows & columns- Easy to analyze- Example: Databases, Excel### Unstructured Data- No fixed format- Example: Text, images, videos### Semi-Structured Data- Partial structure (JSON, XML)

# %% [markdown]
# ## 📊 Structured Data Example| Student_ID | Name | Marks | Grade ||------------|------|-------|-------|| 101 | Ravi | 85 | A || 102 | Sita | 78 | B || 103 | Kumar | 92 | A |- Rows = records- Columns = attributes

# %%
import pandas as pddf = pd.DataFrame({    'Student_ID':[101,102,103],    'Name':['Ravi','Sita','Kumar'],    'Marks':[85,78,92],    'Grade':['A','B','A']})print(df)

# %% [markdown]
# ## 📄 Unstructured Data ExampleText:"Data Science is an evolving field"- No rows/columns- Hard to analyze

# %%
text = "Data Science is powerful"print(text)

# %% [markdown]
# ## 🔗 Semi-Structured Example (JSON){ "Student_ID":101, "Name":"Ravi", "Marks":85}

# %% [markdown]
# ## 📊 Comparison| Feature | Structured | Semi | Unstructured ||--------|-----------|------|--------------|| Format | Table | JSON | None || Analysis | Easy | Medium | Hard |

# %% [markdown]
# ## 🌐 Data Sources- Databases (SQL, NoSQL)- APIs / Web scraping- Sensors & IoT- Social Media- Transactions

# %% [markdown]
# ## 🔄 Data Lifecycle1. Collection2. Cleaning3. Analysis4. Interpretation

# %% [markdown]
# ## 🧹 Data Cleaning- Missing values- Duplicates- Outliers

# %%
# Example missing valuesdf['Marks'] = df['Marks'].fillna(df['Marks'].mean())

# %% [markdown]
# ## 🔄 Data Transformation- Normalization- Encoding- Scaling

# %% [markdown]
# ## ✅ Data Quality- Accuracy- Completeness- Consistency- Validity

# %% [markdown]
# ## 📊 Workflow1. Define problem2. Collect data3. Clean data4. Explore5. Model6. Evaluate7. Communicate

# %%
import matplotlib.pyplot as pltplt.bar(df['Name'], df['Marks'])plt.title("Marks")plt.show()
